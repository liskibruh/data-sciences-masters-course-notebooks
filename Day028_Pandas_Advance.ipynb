# %%
import pandas as pd

df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s = df['Name']
s
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
len(s)
# Out:
# 891

# %%
s = s[0:10]

# %%
l = ['a','b','c','d','e','f','g','h','i','j']

# %%
pd.Series(s, index=l)
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# h    NaN
# i    NaN
# j    NaN
# Name: Name, dtype: object

# %%
s1=pd.Series(list(s),index=l)

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1['a']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2 =s1.append(s)
# Out:
# /tmp/ipykernel_2137/2257867414.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2 =s1.append(s)

# %%
s2
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s2[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2[3]
# Out:
# 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'

# %%
s4 = pd.Series([3,4,5,6,6], index=[2,4,5,6,1])

# %%
s5 = pd.Series([34,345,45,45,454], index=[9,4,5,6,7])

# %%
s6 = s4.append(s5)
# Out:
# /tmp/ipykernel_2137/937876903.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s6 = s4.append(s5)

# %%
s6
# Out:
# 2      3
# 4      4
# 5      5
# 6      6
# 1      6
# 9     34
# 4    345
# 5     45
# 6     45
# 7    454
# dtype: int64

# %%
s6[4]
# Out:
# 4      4
# 4    345
# dtype: int64

# %%
s4
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s5
# Out:
# 9     34
# 4    345
# 5     45
# 6     45
# 7    454
# dtype: int64

# %%
s4*s5
# Out:
# 1       NaN
# 2       NaN
# 4    1380.0
# 5     225.0
# 6     270.0
# 7       NaN
# 9       NaN
# dtype: float64

# %%
s4+s5
# Out:
# 1      NaN
# 2      NaN
# 4    349.0
# 5     50.0
# 6     51.0
# 7      NaN
# 9      NaN
# dtype: float64

# %% [markdown]
# # More

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId', axis=1, inplace = True)

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
d = {
    'key1' : [3,4,5,6,7],
    'key2' : [5,6,7,8,9],
    'key3' : [4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     9     8

# %%
df1=pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df.fillna('sudh')
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3      male  35.0      0      0            373450   8.0500  sudh        S
# 4      male  sudh      0      0            330877   8.4583  sudh        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000  sudh        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female  sudh      1      2        W./C. 6607  23.4500  sudh        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500  sudh        Q
#
# [890 rows x 11 columns]

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#    index                                               Name  Survived  Pclass  \
# 0      0                            Braund, Mr. Owen Harris         0       3
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2      2                             Heikkinen, Miss. Laina         1       3
# 3      3                           Allen, Mr. William Henry         0       3
# 4      4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q

# %%
g = df.groupby('Survived')

# %%
g.sum()
# Out:
# /tmp/ipykernel_2137/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            index  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244315    1390  12985.50    304    181  12142.7199
# 1         151290     666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_2137/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                index    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         445.018215  2.531876  30.626179  0.553734  0.329690  22.117887
# 1         443.665689  1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_2137/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#          index  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99272       135  7076.42     89     77  18124.3125
# 2        81688        87  5168.83     74     70   3801.8417
# 3       214645       119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_2137/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#              index  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       461.730233  0.627907  38.250919  0.413953  0.358140  84.299128
# 2       443.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3       437.158859  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_2137/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#         index                         Name  Survived   Sex   Age  SibSp  \
# Pclass
# 1         888     Young, Miss. Marie Grice         1  male  80.0      3
# 2         885    del Carlo, Mr. Sebastiano         1  male  70.0      3
# 3         889  van Melkebeke, Mr. Philemon         1  male  74.0      8
#
#         Parch      Ticket      Fare
# Pclass
# 1           4   WE/P 5735  512.3292
# 2           3   W/C 14208   73.5000
# 3           6  W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_2137/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
list(df.columns)
# Out:
# ['Name',
#  'Survived',
#  'Pclass',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df5 = df[['Name','Survived','Pclass']][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7=pd.concat([df5,df6], axis=1)

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# 2                                                NaN       NaN     NaN
# 3                                                NaN       NaN     NaN
# 4                                                NaN       NaN     NaN
# 5                            McCarthy, Mr. Timothy J       0.0     1.0
# 6                     Palsson, Master. Gosta Leonard       0.0     3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0     3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)       1.0     2.0
# 9                    Sandstrom, Miss. Marguerite Rut       1.0     3.0

# %%
df7.fillna('sudh')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                               sudh     sudh   sudh
# 6                                               sudh     sudh   sudh
# 7                                               sudh     sudh   sudh
# 8                                               sudh     sudh   sudh
# 9                                               sudh     sudh   sudh
#
#                                                 Name Survived Pclass
# 0                                               sudh     sudh   sudh
# 1                                               sudh     sudh   sudh
# 2                                               sudh     sudh   sudh
# 3                                               sudh     sudh   sudh
# 4                                               sudh     sudh   sudh
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1 = pd.DataFrame({
    'key1':[1,2,3,4,5,6],
    'key2':[4,5,6,7,8,9],
    'key3':[3,4,5,6,7,6]
})

# %%
data2 = pd.DataFrame({
    'key1':[1,2,3,74,57,76],
    'key4':[4,5,6,76,87,98],
    'key5':[3,4,65,66,74,62]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     7
# 5     6     9     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4     3
# 1     2     5     4
# 2     3     6    65
# 3    74    76    66
# 4    57    87    74
# 5    76    98    62

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3     4     3
# 1     2     5     4     5     4
# 2     3     6     5     6    65

# %%
pd.merge(data1,data2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3   4.0   3.0
# 1     2     5     4   5.0   4.0
# 2     3     6     5   6.0  65.0
# 3     4     7     6   NaN   NaN
# 4     5     8     7   NaN   NaN
# 5     6     9     6   NaN   NaN

# %%
pd.merge(data1,data2, how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     4     3
# 1     2   5.0   4.0     5     4
# 2     3   6.0   5.0     6    65
# 3    74   NaN   NaN    76    66
# 4    57   NaN   NaN    87    74
# 5    76   NaN   NaN    98    62

# %%
pd.merge(data1,data2, how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   4.0   3.0
# 1     2   5.0   4.0   5.0   4.0
# 2     3   6.0   5.0   6.0  65.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0   7.0   NaN   NaN
# 5     6   9.0   6.0   NaN   NaN
# 6    74   NaN   NaN  76.0  66.0
# 7    57   NaN   NaN  87.0  74.0
# 8    76   NaN   NaN  98.0  62.0

# %%
pd.merge(data1,data2, how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1     4     3
# 1        1     4     3       2     5     4
# 2        1     4     3       3     6    65
# 3        1     4     3      74    76    66
# 4        1     4     3      57    87    74
# 5        1     4     3      76    98    62
# 6        2     5     4       1     4     3
# 7        2     5     4       2     5     4
# 8        2     5     4       3     6    65
# 9        2     5     4      74    76    66
# 10       2     5     4      57    87    74
# 11       2     5     4      76    98    62
# 12       3     6     5       1     4     3
# 13       3     6     5       2     5     4
# 14       3     6     5       3     6    65
# 15       3     6     5      74    76    66
# 16       3     6     5      57    87    74
# 17       3     6     5      76    98    62
# 18       4     7     6       1     4     3
# 19       4     7     6       2     5     4
# 20       4     7     6       3     6    65
# 21       4     7     6      74    76    66
# 22       4     7     6      57    87    74
# 23       4     7     6      76    98    62
# 24       5     8     7       1     4     3
# 25       5     8     7       2     5     4
# 26       5     8     7       3     6    65
# 27       5     8     7      74    76    66
# 28       5     8     7      57    87    74
# 29       5     8     7      76    98    62
# 30       6     9     6       1     4     3
# 31       6     9     6       2     5     4
# 32       6     9     6       3     6    65
# 33       6     9     6      74    76    66
# 34       6     9     6      57    87    74
# 35       6     9     6      76    98    62

# %%
pd.merge(data1,data2, how='outer', on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   4.0   3.0
# 1     2   5.0   4.0   5.0   4.0
# 2     3   6.0   5.0   6.0  65.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0   7.0   NaN   NaN
# 5     6   9.0   6.0   NaN   NaN
# 6    74   NaN   NaN  76.0  66.0
# 7    57   NaN   NaN  87.0  74.0
# 8    76   NaN   NaN  98.0  62.0

# %%
data1 = pd.DataFrame({
    'key1':[1,2,3,4,5,6],
    'key2':[4,5,6,7,8,9],
    'key3':[3,4,5,6,7,6]
},
index = ['a','b','c','d','e','f'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     5     8     7
# f     6     9     6

# %%
data2= pd.DataFrame({
    'key11':[1,2,3,4,5,6],
    'key22':[4,5,6,7,8,9],
    'key33':[3,4,5,6,7,6]
},
index = ['a','b','h','i','j','k'])

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      3      6      5
# i      4      7      6
# j      5      8      7
# k      6      9      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     3     6     5    NaN    NaN    NaN
# d     4     7     6    NaN    NaN    NaN
# e     5     8     7    NaN    NaN    NaN
# f     6     9     6    NaN    NaN    NaN

# %%
data1.join(data2, how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      3      6      5
# i   NaN   NaN   NaN      4      7      6
# j   NaN   NaN   NaN      5      8      7
# k   NaN   NaN   NaN      6      9      6

# %%
data1.join(data2, how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2, how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   3.0   6.0   5.0    NaN    NaN    NaN
# d   4.0   7.0   6.0    NaN    NaN    NaN
# e   5.0   8.0   7.0    NaN    NaN    NaN
# f   6.0   9.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    3.0    6.0    5.0
# i   NaN   NaN   NaN    4.0    7.0    6.0
# j   NaN   NaN   NaN    5.0    8.0    7.0
# k   NaN   NaN   NaN    6.0    9.0    6.0

# %%
data1.join(data2, how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      3      6      5
# 3      1     4     3      4      7      6
# 4      1     4     3      5      8      7
# 5      1     4     3      6      9      6
# 6      2     5     4      1      4      3
# 7      2     5     4      2      5      4
# 8      2     5     4      3      6      5
# 9      2     5     4      4      7      6
# 10     2     5     4      5      8      7
# 11     2     5     4      6      9      6
# 12     3     6     5      1      4      3
# 13     3     6     5      2      5      4
# 14     3     6     5      3      6      5
# 15     3     6     5      4      7      6
# 16     3     6     5      5      8      7
# 17     3     6     5      6      9      6
# 18     4     7     6      1      4      3
# 19     4     7     6      2      5      4
# 20     4     7     6      3      6      5
# 21     4     7     6      4      7      6
# 22     4     7     6      5      8      7
# 23     4     7     6      6      9      6
# 24     5     8     7      1      4      3
# 25     5     8     7      2      5      4
# 26     5     8     7      3      6      5
# 27     5     8     7      4      7      6
# 28     5     8     7      5      8      7
# 29     5     8     7      6      9      6
# 30     6     9     6      1      4      3
# 31     6     9     6      2      5      4
# 32     6     9     6      3      6      5
# 33     6     9     6      4      7      6
# 34     6     9     6      5      8      7
# 35     6     9     6      6      9      6

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df['Fare_INR']=df['Fare'].apply(lambda x:x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
def euro_to_inr(x):
    return x*80

df['Fare_INR']=df['Fare'].apply(euro_to_inr)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# 3   644.000        24
# 4   676.664        16

# %%
def cat_fare(x):
    if x<10:
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df['cat_fare']=df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len cat_fare
# 0   580.000        23    cheap
# 1  5702.664        51     high
# 2   634.000        22    cheap
# 3   644.000        24    cheap
# 4   676.664        16    cheap

# %% [markdown]
# # More

# %%
import pandas as pd

data = {
    'a': [1,2,3,4],
    'b': [4,5,6,7],
    'c': ['sudh','krish','hitesh','naveen']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7  naveen

# %%
df.set_index('a')
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   krish
# 3  6  hitesh
# 4  7  naveen

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7  naveen

# %%
df.set_index('a',inplace = True)

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   krish
# 3  6  hitesh
# 4  7  naveen

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7  naveen

# %%
import pandas as pd

data = {
    'col_a': [1,2,3,4],
    'col_b': [4,5,6,7],
    'col_c': ['sudh','krish','hitesh','naveen']
}

df1= pd.DataFrame(data, index=['a','b','c','d'])

# %%
df1
# Out:
#    col_a  col_b   col_c
# a      1      4    sudh
# b      2      5   krish
# c      3      6  hitesh
# d      4      7  naveen

# %%
df1=df1.reindex(['b','c','d','a'])
df1
# Out:
#    col_a  col_b   col_c
# b      2      5   krish
# c      3      6  hitesh
# d      4      7  naveen
# a      1      4    sudh

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('b', col_a        2
# col_b        5
# col_c    krish
# Name: b, dtype: object)
# ('c', col_a         3
# col_b         6
# col_c    hitesh
# Name: c, dtype: object)
# ('d', col_a         4
# col_b         7
# col_c    naveen
# Name: d, dtype: object)
# ('a', col_a       1
# col_b       4
# col_c    sudh
# Name: a, dtype: object)

# %%
for i,j in df1.iterrows():
    print(i, j)
# Out:
# b col_a        2
# col_b        5
# col_c    krish
# Name: b, dtype: object
# c col_a         3
# col_b         6
# col_c    hitesh
# Name: c, dtype: object
# d col_a         4
# col_b         7
# col_c    naveen
# Name: d, dtype: object
# a col_a       1
# col_b       4
# col_c    sudh
# Name: a, dtype: object

# %%
for i,j in df1.iterrows():
    print(j)
# Out:
# col_a        2
# col_b        5
# col_c    krish
# Name: b, dtype: object
# col_a         3
# col_b         6
# col_c    hitesh
# Name: c, dtype: object
# col_a         4
# col_b         7
# col_c    naveen
# Name: d, dtype: object
# col_a       1
# col_b       4
# col_c    sudh
# Name: a, dtype: object

# %%
for i,j in df1.iterrows():
    print(i)
# Out:
# b
# c
# d
# a

# %%
for i in df1.iteritems():
    print(i)
# Out:
# ('col_a', b    2
# c    3
# d    4
# a    1
# Name: col_a, dtype: int64)
# ('col_b', b    5
# c    6
# d    7
# a    4
# Name: col_b, dtype: int64)
# ('col_c', b     krish
# c    hitesh
# d    naveen
# a      sudh
# Name: col_c, dtype: object)
# /tmp/ipykernel_2137/549805685.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in df1.iteritems():

# %%
for i,j in df1.iteritems():
    print(i)
# Out:
# col_a
# col_b
# col_c
# /tmp/ipykernel_2137/1974115245.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i,j in df1.iteritems():

# %%
for i,j in df1.iteritems():
    print(j)
# Out:
# b    2
# c    3
# d    4
# a    1
# Name: col_a, dtype: int64
# b    5
# c    6
# d    7
# a    4
# Name: col_b, dtype: int64
# b     krish
# c    hitesh
# d    naveen
# a      sudh
# Name: col_c, dtype: object
# /tmp/ipykernel_2137/495810906.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i,j in df1.iteritems():

# %%
for col_name, column in df1.iteritems():
    print(col_name, column)
# Out:
# col_a b    2
# c    3
# d    4
# a    1
# Name: col_a, dtype: int64
# col_b b    5
# c    6
# d    7
# a    4
# Name: col_b, dtype: int64
# col_c b     krish
# c    hitesh
# d    naveen
# a      sudh
# Name: col_c, dtype: object
# /tmp/ipykernel_2137/3992656291.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, column in df1.iteritems():

# %%
df1
# Out:
#    col_a  col_b   col_c
# b      2      5   krish
# c      3      6  hitesh
# d      4      7  naveen
# a      1      4    sudh

# %%
[i for i in df1['col_a']]
# Out:
# [2, 3, 4, 1]

# %%
list(df1['col_a'])
# Out:
# [2, 3, 4, 1]

# %%
df1['col_a'].sum()
# Out:
# 10

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# col_a                       10
# col_b                       22
# col_c    krishhiteshnaveensudh
# dtype: object

# %%
df2 = df1[['col_a','col_b']]

# %%
df2
# Out:
#    col_a  col_b
# b      2      5
# c      3      6
# d      4      7
# a      1      4

# %%
df2.applymap(lambda x: x**2)
# Out:
#    col_a  col_b
# b      4     25
# c      9     36
# d     16     49
# a      1     16

# %%
df1
# Out:
#    col_a  col_b   col_c
# b      2      5   krish
# c      3      6  hitesh
# d      4      7  naveen
# a      1      4    sudh

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  6  hitesh
# 1  2  5   krish
# 3  4  7  naveen
# 0  1  4    sudh

# %%
df.sort_index()
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7  naveen

# %%
df.sort_index(ascending=False)
# Out:
#    a  b       c
# 3  4  7  naveen
# 2  3  6  hitesh
# 1  2  5   krish
# 0  1  4    sudh

# %%
df3 = pd.DataFrame({'Desc': ["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language."]})

# %%
df3
# Out:
#                                                 Desc
# 0  Data Science Masters course is highly curated ...

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.

# %%
df3 = pd.DataFrame({'Desc': ["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.", "my name is sudh","use to teach data science"]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      use to teach data science

# %%
df3['len']=df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      use to teach data science
#
#    len
# 0  765
# 1   15
# 2   25

# %%
df3['word_count']=df3['Desc'].apply(lambda x: len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# 0  Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                my name is sudh
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      use to teach data science
#
#    len  word_count
# 0  765         104
# 1   15           4
# 2   25           5

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7  naveen

# %%
df['a'].mean()
# Out:
# 2.5

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].min()
# Out:
# 1

# %%
df['a'].max()
# Out:
# 4

# %%
df4=pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df4['a']
# Out:
# 0    3
# 1    4
# 2    5
# 3    2
# 4    1
# 5    3
# 6    4
# 7    5
# 8    6
# Name: a, dtype: int64

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).sum()
# Out:
# 0     NaN
# 1     NaN
# 2    12.0
# 3    11.0
# 4     8.0
# 5     6.0
# 6     8.0
# 7    12.0
# 8    15.0
# Name: a, dtype: float64

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %% [markdown]
# ### Date data in pandas

# %%
dates = pd.date_range(start = '2023-04-23', end = '2023-06-23')

# %%
dates
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
#                '2023-06-14', '2023-06-15', '2023-06-16', '2023-06-17',
#                '2023-06-18', '2023-06-19', '2023-06-20', '2023-06-21',
#                '2023-06-22', '2023-06-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date=pd.DataFrame({'dates': dates})

# %%
df_date
# Out:
#         dates
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# dates    datetime64[ns]
# dtype: object

# %%
df7=pd.DataFrame({'date':['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
               '2023-04-27']})

# %%
df7
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['updated_date'] = pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date updated_date
# 0  2023-04-23   2023-04-23
# 1  2023-04-24   2023-04-24
# 2  2023-04-25   2023-04-25
# 3  2023-04-26   2023-04-26
# 4  2023-04-27   2023-04-27

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df7['year'] = df7['updated_date'].dt.year

# %%
df7
# Out:
#          date updated_date  year
# 0  2023-04-23   2023-04-23  2023
# 1  2023-04-24   2023-04-24  2023
# 2  2023-04-25   2023-04-25  2023
# 3  2023-04-26   2023-04-26  2023
# 4  2023-04-27   2023-04-27  2023

# %%
df7['day'] = df7['updated_date'].dt.day

# %%
df7['month'] = df7['updated_date'].dt.month

# %%
df7
# Out:
#          date updated_date  year  day  month
# 0  2023-04-23   2023-04-23  2023   23      4
# 1  2023-04-24   2023-04-24  2023   24      4
# 2  2023-04-25   2023-04-25  2023   25      4
# 3  2023-04-26   2023-04-26  2023   26      4
# 4  2023-04-27   2023-04-27  2023   27      4

# %%
pd.Timedelta(days=1, hours=5, minutes=45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2023-04-23')

# %%
td = pd.Timedelta(days = 1)

# %%
dt+td
# Out:
# Timestamp('2023-04-24 00:00:00')

# %% [markdown]
# #### Categorical in pandas

# %%
data = ['sudh','krish','hitesh','navin','sudh','sudh']

# %%
cat = pd.Categorical(data)

# %%
cat.value_counts()
# Out:
# hitesh    1
# krish     1
# navin     1
# sudh      3
# dtype: int64

# %% [markdown]
# #### Data viz in pandas

# %%
d = pd.Series([1,2,3,3,4,5,5,6,7,8])

# %%
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# 5    5
# 6    5
# 7    6
# 8    7
# 9    8
# dtype: int64

# %%
d.plot()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,6,7,8]})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot(x = 'a', y = 'b')
# Out:
# <AxesSubplot: xlabel='a'>

# %%
df.plot.scatter(x = 'a', y = 'b')
# Out:
# <AxesSubplot: xlabel='a', ylabel='b'>

# %%
d = pd.Series([1,2,3,3,4,5,5,6,7,8])

# %%
d.plot.pie()
# Out:
# <AxesSubplot: >
