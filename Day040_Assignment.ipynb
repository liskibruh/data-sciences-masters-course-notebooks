# %% [markdown]
# # Question No. 1:
# Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.
#
# ## Answer:

# %%
import scipy.stats as stats

sample_mean = 50
sample_std = 5
sample_size = 100 

#calculate the standard error of the mean
std_error = sample_std / (sample_size ** 0.5)

#calculate the confidence interval using the t-distribution
t_value = stats.t.ppf(0.975, sample_size-1)
lower_ci = sample_mean - t_value * std_error
upper_ci = sample_mean + t_value * std_error

#print the results
print(f"The 95% confidence interval is [{lower_ci:.2f}, {upper_ci:.2f}]")
# Out:
# The 95% confidence interval is [49.01, 50.99]

# %% [markdown]
# # Question No. 2:
# Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.
#
# ## Answer:

# %%
import numpy as np
import scipy.stats as stats

# observed counts of each color in a sample of M&Ms
observed_counts = np.array([45, 35, 15, 10, 5, 35])

# expected counts based on the expected distribution
expected_counts = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.2]) * np.sum(observed_counts)

# conduct the chi-square test
chi2, p = chisquare(observed_counts, expected_counts)

significance_value=0.05
confidence_interval=1-0.05
dof= len(expected_counts)-1
critical_value=stats.chi2.ppf(confidence_interval,dof)

# print the results
print(f"chi-square statistic = {chi2:.2f}")
print(f"p-value = {p:.4f}")

if chisquare_stat > critical_value:
    print("Reject the null hypothesis")
else:
    print("Failed to reject null hypothsis")
# Out:
# chi-square statistic = 25.69
# p-value = 0.0001
# Reject the null hypothesis

# %% [markdown]
# # Question No. 3:
# Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:
#
# ![image.png](attachment:image.png)
#
# ## Answer:

# %%
import numpy as np
from scipy.stats import chi2_contingency

observed = np.array([[20, 15], [10, 25], [15, 20]])

#conduct the chi-square test
chi2, p, dof, expected = chi2_contingency(observed)

print(f"chi-square statistic = {chi2:.2f}")
print(f"p-value = {p:.4f}")
# Out:
# chi-square statistic = 5.83
# p-value = 0.0541

# %% [markdown]
# **Interpretation:**<br>
# The chi-square statistic is 5.83 and the p-value is 0.0541. Since the p-value is greater than the significance level of 0.05, we fail to reject the null hypothesis that there is no association between the two categorical variables (group and outcome). Therefore, we conclude that there is not enough evidence to suggest that the proportions of outcomes are different between Group A and Group B.

# %% [markdown]
# # Question No. 4:
# A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.
#
# ## Answer:

# %%
import statsmodels.stats.proportion as proportion

#number of individuals who smoked
smokers = 60

#total number of individuals
sample_size = 500

# estimate of the proportion of smokers in the population
p_hat = smokers / sample_size

# calculate the confidence interval
conf_int = proportion.proportion_confint(count=smokers, nobs=sample_size, alpha=0.05)

# print the results
print(f"The 95% confidence interval for the true proportion of smokers in the population is [{conf_int[0]}, {conf_int[1]}]")
# Out:
# The 95% confidence interval for the true proportion of smokers in the population is [0.09151638887130706, 0.14848361112869293]

# %% [markdown]
# # Question No. 5:
# Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.
#
# ## Answer:

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12

#sample size (assumed)
n = 100

std_error = sample_std / (n ** 0.5)

#calculate the z-value for 90% confidence level
z_value = stats.norm.ppf(0.95)

#calculate the confidence interval
lower = sample_mean - z_value * std_error
upper = sample_mean + z_value * std_error

print(f"The 90% confidence interval is [{lower}, {upper}]")
# Out:
# The 90% confidence interval is [73.02617564765823, 76.97382435234177]

# %% [markdown]
# # Question No. 6:
# Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.
#
# ## Answer:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df = 10

#create the x-axis values for the plot
x = np.linspace(0, 30, 500)

#create the chi-square distribution
chi = chi2(df)

plt.plot(x, chi.pdf(x), label=f'df={df}')

# shade the area corresponding to a chi-square statistic of 15
x_shade = np.linspace(15, 30, 500)
y_shade = chi.pdf(x_shade)
plt.fill_between(x_shade, y_shade, where=x_shade > 15, color='orange')
plt.xlabel('chi-square statistic')
plt.ylabel('Probability density')
plt.title(f'Chi-square distribution with {df} degrees of freedom')
plt.legend()
plt.show()

# %% [markdown]
# # Question No. 7:
# A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.
#
# ## Answer:
# **Final answer:**<br>
# > The 99% confidence interval for true proportion of people in population who prefer Coke is:<br>0.471-0.569
#
# **Detailed answer in the attached photos**
#
# ![IMG-20230313-WA0002.jpg](attachment:IMG-20230313-WA0002.jpg)

# %% [markdown]
# # Question No. 8:
# A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.
#
# ## Answer:
# **Final answer:**<br>
# >Chi-square stat.=1 and Critical value=3.845<br>Failed to reject null hypothesis
#
# **Detailed answer in the attached photos**
#
# ![IMG-20230313-WA0007.jpg](attachment:IMG-20230313-WA0007.jpg)

# %% [markdown]
# ![IMG-20230313-WA0006.jpg](attachment:IMG-20230313-WA0006.jpg)

# %% [markdown]
# # Question No. 9:
# A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.
# ![image.png](attachment:image.png)
# Use a significance level of 0.05.
#
# ## Answer:
# **Final answer:**<br>
# >Chi-square stat.=12.9 and Critical value=3.841<br>Reject null hypothesis
#
# **Detailed answer in the attached photos**

# %% [markdown]
# ![IMG-20230313-WA0003.jpg](attachment:IMG-20230313-WA0003.jpg)

# %% [markdown]
# ![IMG-20230313-WA0012.jpg](attachment:IMG-20230313-WA0012.jpg)

# %% [markdown]
# ![IMG-20230313-WA0005.jpg](attachment:IMG-20230313-WA0005.jpg)

# %% [markdown]
# # Question No. 10:
# A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin.
#
# ![image.png](attachment:image.png)
# Use a significance level of 0.01.
# ## Answer:
# **Final answer:**<br>
# >Chi-square stat.=13.392 and Critical value=4.605<br>Reject null hypothesis
#
# **Detailed answer in the attached photos**

# %% [markdown]
# ![IMG-20230313-WA0011.jpg](attachment:IMG-20230313-WA0011.jpg)

# %% [markdown]
# ![IMG-20230313-WA0009.jpg](attachment:IMG-20230313-WA0009.jpg)

# %% [markdown]
# ![IMG-20230313-WA0008.jpg](attachment:IMG-20230313-WA0008.jpg)

# %% [markdown]
# ![IMG-20230313-WA0004.jpg](attachment:IMG-20230313-WA0004.jpg)

# %% [markdown]
# # Question No. 11:
# A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.
#
# ## Answer:
# **Final answer:**<br>
# >T-stat. = 1.414 and Critical Value = 2.045<br>Failed to reject null hypothesis
#
# **Detailed answer in the attached photos**
# ![IMG-20230313-WA0010.jpg](attachment:IMG-20230313-WA0010.jpg)

# %% [markdown]
# ![IMG-20230313-WA0001.jpg](attachment:IMG-20230313-WA0001.jpg)
